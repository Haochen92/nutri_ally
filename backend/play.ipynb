# %%
from sqlmodel import Field, SQLModel, create_engine, Session, select
from database import engine, User
# Code below omitted 👇

# %%
with Session(engine) as session:
    user = User(name="alice", password="$2b$12$cKpJPT946v.4tTR4/urAUOEIVLqdk30IEZ27gVr2DHRX6QD1Sj84a")
    session.add(user)
    session.commit()
# Out:
# 2024-11-08 13:09:14,949 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-11-08 13:09:14,952 INFO sqlalchemy.engine.Engine INSERT INTO user (name, password) VALUES (?, ?)
# 2024-11-08 13:09:14,953 INFO sqlalchemy.engine.Engine [generated in 0.00081s] ('alice', '$2b$12$cKpJPT946v.4tTR4/urAUOEIVLqdk30IEZ27gVr2DHRX6QD1Sj84a')
# 2024-11-08 13:09:14,954 INFO sqlalchemy.engine.Engine COMMIT

# %%
with Session(engine) as session:
    res = session.get(User, "alice")
    print(res)
# Out:
# 2024-11-08 13:15:33,809 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-11-08 13:15:33,812 INFO sqlalchemy.engine.Engine SELECT user.name AS user_name, user.password AS user_password
# FROM user
# WHERE user.name = ?
# 2024-11-08 13:15:33,813 INFO sqlalchemy.engine.Engine [generated in 0.00073s] ('alice',)
# password='$2b$12$cKpJPT946v.4tTR4/urAUOEIVLqdk30IEZ27gVr2DHRX6QD1Sj84a' name='alice'
# 2024-11-08 13:15:33,814 INFO sqlalchemy.engine.Engine ROLLBACK
